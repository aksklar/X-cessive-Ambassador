# %%
import omdb
import pandas as pd
import csv
from pprint import pprint

# %%
df=pd.read_csv('data/movies_7k(400).csv')
df.head()
# Out:
#    movieId                               title   imdbId
# 0    90376  We Need to Talk About Kevin (2011)  1242460
# 1    87529                Your Highness (2011)  1240982
# 2    76272       Five Minutes of Heaven (2009)  1238291
# 3    66596                 Mystery Team (2009)  1237838
# 4    89203                   Magic Trip (2011)  1235790

# %%
len(df)
# Out:
# 100

# %%
movie_list=df['imdbId'].tolist()

# %%
movie_counter = 1
full_plot=[]
for movie in movie_list:
    try:
        res= omdb.request(i='tt'+str(movie), plot='full',apikey='bbd62e62')
        data=res.json()
        print(f"Processing Record {movie_counter} | {data['Title']}")
        full_plot.append({"Title":data['Title'], "Year":data['Year'], "Plot":data['Plot'], "Genres":data['Genre']})
        movie_counter += 1
    except:
        print(f"Data does not exist for this movie: {data['Title']}")
        continue
print("Done Retrieving Records")
# Out:
# Processing Record 1 | We Need to Talk About Kevin
# Processing Record 2 | Your Highness
# Processing Record 3 | Five Minutes of Heaven
# Processing Record 4 | Mystery Team
# Processing Record 5 | Magic Trip: Ken Kesey's Search for a Kool Place
# Processing Record 6 | The Future
# Processing Record 7 | A Prophet
# Processing Record 8 | Dorian Gray
# Processing Record 9 | Greenberg
# Processing Record 10 | The Men Who Stare at Goats
# Processing Record 11 | The Butterfly Effect 3: Revelations
# Data does not exist for this movie: The Butterfly Effect 3: Revelations
# Data does not exist for this movie: The Butterfly Effect 3: Revelations
# Processing Record 12 | Involuntary
# Processing Record 13 | Fish Tank
# Processing Record 14 | Hot Tub Time Machine
# Processing Record 15 | Due Date
# Data does not exist for this movie: Due Date
# Data does not exist for this movie: Due Date
# Processing Record 16 | Jane Eyre
# Processing Record 17 | It Might Get Loud
# ...

# %%
full_plot
# Out:
# [{'Genres': 'Drama, Mystery, Thriller',
#   'Plot': 'Eva Khatchadourian is trying to piece together her life following the "incident". Once a successful travel writer, she is forced to take whatever job comes her way, which of late is as a clerk in a travel agency. She lives a solitary life as people who know about her situation openly shun her, even to the point of violent actions toward her. She, in turn, fosters that solitary life because of the incident, the aftermath of which has turned her into a meek and scared woman. That incident involved her son Kevin Khatchadourian, who is now approaching his eighteenth birthday. Eva and Kevin have always had a troubled relationship, even when he was an infant. Whatever troubles he saw, Franklin, Eva\'s complacent husband, just attributed it to Kevin being a typical boy. The incident may be seen by both Kevin and Eva as his ultimate act in defiance against his mother.',
#   'Title': 'We Need to Talk About Kevin',
#   'Year': '2011'},
# ...

# %%
len(full_plot)
# Out:
# 82

# %%
movie_df=pd.DataFrame(full_plot)

# %%
movie_df=movie_df[["Title", "Year", "Genres", "Plot"]]

# %%
movie_df.head(20)
# Out:
#                                               Title  Year  \
# 0                       We Need to Talk About Kevin  2011
# 1                                     Your Highness  2011
# 2                            Five Minutes of Heaven  2009
# 3                                      Mystery Team  2009
# 4   Magic Trip: Ken Kesey's Search for a Kool Place  2011
# 5                                        The Future  2011
# 6                                         A Prophet  2009
# 7                                       Dorian Gray  2009
# 8                                         Greenberg  2010
# 9                        The Men Who Stare at Goats  2009
# 10              The Butterfly Effect 3: Revelations  2009
# 11                                      Involuntary  2008
# 12                                        Fish Tank  2009
# 13                             Hot Tub Time Machine  2010
# 14                                         Due Date  2010
# ...

# %%
movie_df.to_csv('movies7_full_82.csv', index=False)
