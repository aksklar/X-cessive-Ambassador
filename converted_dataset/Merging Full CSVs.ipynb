# %%
# Import Dependencies
import glob
import pandas as pd
import os

# %%
# Use glob to load all CSVs
path = r"full_movie_data"
all_files = glob.glob(os.path.join(path, "*.csv"))
records_df = [pd.read_csv(file) for file in all_files]
print(records_df)
# Out:
# [                               Title  Year  Rated  \
# 0                          Toy Story  1995      G
# 1                            Jumanji  1995     PG
# 2                   Grumpier Old Men  1995  PG-13
# 3                  Waiting to Exhale  1995      R
# 4        Father of the Bride Part II  1995     PG
# 5                       Tom and Huck  1995     PG
# 6                       Sudden Death  1995      R
# 7                          GoldenEye  1995  PG-13
# 8                              Balto  1995      G
# 9                              Nixon  1995      R
# 10                  Cutthroat Island  1995  PG-13
# 11                            Casino  1995      R
# 12             Sense and Sensibility  1995     PG
# 13                        Four Rooms  1995      R
# 14    Ace Ventura: When Nature Calls  1995  PG-13
# 15                       Money Train  1995      R
# 16                        Get Shorty  1995      R
# 17                           Copycat  1995      R
# ...

# %%
full_movie_data_mega= pd.concat(records_df, ignore_index=True)

# %%
full_movie_data_mega
# Out:
#                               Title  Year  Rated  \
# 0                         Toy Story  1995      G
# 1                           Jumanji  1995     PG
# 2                  Grumpier Old Men  1995  PG-13
# 3                 Waiting to Exhale  1995      R
# 4       Father of the Bride Part II  1995     PG
# 5                      Tom and Huck  1995     PG
# 6                      Sudden Death  1995      R
# 7                         GoldenEye  1995  PG-13
# 8                             Balto  1995      G
# 9                             Nixon  1995      R
# 10                 Cutthroat Island  1995  PG-13
# 11                           Casino  1995      R
# 12            Sense and Sensibility  1995     PG
# 13                       Four Rooms  1995      R
# 14   Ace Ventura: When Nature Calls  1995  PG-13
# 15                      Money Train  1995      R
# 16                       Get Shorty  1995      R
# 17                          Copycat  1995      R
# ...

# %%
full_movie_data_mega.to_csv("full_movie_data.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e1c85f9f1af7> in <module>()
# ----> 1 full_movie_data.to_csv("full_movie_data.csv", index=False)
#
# NameError: name 'full_movie_data' is not defined
