# %%
import omdb
import pandas as pd
import csv
from pprint import pprint

# %%
df=pd.read_csv('data/movies_100.csv')
df.head()
# Out:
#    movieId                               title  imdbId
# 0        1                    Toy Story (1995)  114709
# 1        2                      Jumanji (1995)  113497
# 2        3             Grumpier Old Men (1995)  113228
# 3        4            Waiting to Exhale (1995)  114885
# 4        5  Father of the Bride Part II (1995)  113041

# %%
len(df)
# Out:
# 100

# %%
movie_list=df['imdbId'].tolist()

# %%
movie_counter = 1
full_plot=[]
for movie in movie_list:
    try:
        res= omdb.request(i='tt0'+str(movie), plot='full',apikey='f43f79fb')
        data=res.json()
        print(f"Processing Record {movie_counter} | {data['Title']}")
        full_plot.append({"Title":data['Title'], "Year":data['Year'], "Plot":data['Plot'], "Rated":data['Rated'], "Genre(s)":data['Genre']})
        movie_counter += 1
    except:
        print(f"Data does not exist for this movie: {data['Title']}")
        continue
print("Done Retrieving Records")
# Out:
# Processing Record 1 | Toy Story
# Processing Record 2 | Jumanji
# Processing Record 3 | Grumpier Old Men
# Processing Record 4 | Waiting to Exhale
# Processing Record 5 | Father of the Bride Part II
# Data does not exist for this movie: Father of the Bride Part II
# Data does not exist for this movie: Father of the Bride Part II
# Processing Record 6 | Tom and Huck
# Processing Record 7 | Sudden Death
# Processing Record 8 | GoldenEye
# Data does not exist for this movie: GoldenEye
# Data does not exist for this movie: GoldenEye
# Processing Record 9 | Balto
# Processing Record 10 | Nixon
# Processing Record 11 | Cutthroat Island
# Processing Record 12 | Casino
# Processing Record 13 | Sense and Sensibility
# Processing Record 14 | Four Rooms
# Processing Record 15 | Ace Ventura: When Nature Calls
# Processing Record 16 | Money Train
# Processing Record 17 | Get Shorty
# Processing Record 18 | Copycat
# Processing Record 19 | Assassins
# Processing Record 20 | Powder
# ...

# %%
full_plot
# Out:
# [{'Genre(s)': 'Animation, Adventure, Comedy',
#   'Plot': 'A little boy named Andy loves to be in his room, playing with his toys, especially his doll named "Woody". But, what do the toys do when Andy is not with them, they come to life. Woody believes that he has life (as a toy) good. However, he must worry about Andy\'s family moving, and what Woody does not know is about Andy\'s birthday party. Woody does not realize that Andy\'s mother gave him an action figure known as Buzz Lightyear, who does not believe that he is a toy, and quickly becomes Andy\'s new favorite toy. Woody, who is now consumed with jealousy, tries to get rid of Buzz. Then, both Woody and Buzz are now lost. They must find a way to get back to Andy before he moves without them, but they will have to pass through a ruthless toy killer, Sid Phillips.',
#   'Rated': 'G',
#   'Title': 'Toy Story',
#   'Year': '1995'},
#  {'Genre(s)': 'Adventure, Family, Fantasy',
# ...

# %%
len(full_plot)
# Out:
# 86

# %%
movie_df=pd.DataFrame(full_plot)

# %%
movie_df=movie_df[["Title", "Year", "Rated", "Genre(s)", "Plot"]]

# %%
movie_df.head(20)
# Out:
#                              Title  Year  Rated                      Genre(s)  \
# 0                        Toy Story  1995      G  Animation, Adventure, Comedy
# 1                          Jumanji  1995     PG    Adventure, Family, Fantasy
# 2                 Grumpier Old Men  1995  PG-13               Comedy, Romance
# 3                Waiting to Exhale  1995      R        Comedy, Drama, Romance
# 4      Father of the Bride Part II  1995     PG       Comedy, Family, Romance
# 5                     Tom and Huck  1995     PG      Adventure, Comedy, Drama
# 6                     Sudden Death  1995      R       Action, Crime, Thriller
# 7                        GoldenEye  1995  PG-13   Action, Adventure, Thriller
# 8                            Balto  1995      G   Animation, Adventure, Drama
# 9                            Nixon  1995      R     Biography, Drama, History
# 10                Cutthroat Island  1995  PG-13     Action, Adventure, Comedy
# ...

# %%
movie_df.to_csv('movies1_full_92.csv', index=False)
