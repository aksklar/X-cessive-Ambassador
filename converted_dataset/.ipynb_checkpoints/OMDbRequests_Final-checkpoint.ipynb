# %%
import omdb
import pandas as pd
import csv
from pprint import pprint

# %%
df=pd.read_csv('data/movies_8k(600).csv')
df.head()
# Out:
#    movieId                                  title   imdbId
# 0   110553        The Amazing Spider-Man 2 (2014)  1872181
# 1    97870  Sessions, The (Surrogate, The) (2012)  1866249
# 2   117444                 Song of the Sea (2014)  1865505
# 3    95088           Safety Not Guaranteed (2012)  1862079
# 4    93324                      Undefeated (2011)  1860355

# %%
len(df)
# Out:
# 100

# %%
movie_list=df['imdbId'].tolist()

# %%
movie_counter = 1
full_plot=[]
for movie in movie_list:
    try:
        res= omdb.request(i='tt'+str(movie), plot='full',apikey='f43f79fb')
        data=res.json()
        print(f"Processing Record {movie_counter} | {data['Title']}")
        full_plot.append({"Title":data['Title'], "Year":data['Year'], "Plot":data['Plot'], "Rated":data['Rated'], "Genre(s)":data['Genre']})
        movie_counter += 1
    except:
        print(f"Data does not exist for this movie: {data['Title']}")
        continue
print("Done Retrieving Records")
# Out:
# Processing Record 1 | The Amazing Spider-Man 2
# Processing Record 2 | The Sessions
# Processing Record 3 | Song of the Sea
# Processing Record 4 | Safety Not Guaranteed
# Processing Record 5 | Undefeated
# Processing Record 6 | Turbo
# Processing Record 7 | To Rome with Love
# Processing Record 8 | Resident Evil: Retribution
# Processing Record 9 | End of Watch
# Processing Record 10 | Percy Jackson: Sea of Monsters
# Processing Record 11 | Snow White
# Processing Record 12 | You're Next
# Processing Record 13 | Django Unchained
# Processing Record 14 | Why Stop Now?
# Processing Record 15 | The Loft
# Processing Record 16 | Game Change
# Processing Record 17 | Bad Karma
# Processing Record 18 | Ai Weiwei: Never Sorry
# Processing Record 19 | Inescapable
# Processing Record 20 | Captain America: The Winter Soldier
# Processing Record 21 | Divergent
# Processing Record 22 | Ruby Sparks
# Processing Record 23 | Gone
# Processing Record 24 | Winter's Tale
# ...

# %%
full_plot
# Out:
# [{'Genre(s)': 'Action, Adventure, Sci-Fi',
#   'Plot': "We've always known that Spider-Man's most important conflict has been within himself: the struggle between the ordinary obligations of Peter Parker and the extraordinary responsibilities of Spider-Man. But in The Amazing Spider-Man 2, Peter Parker finds that his greatest battle is about to begin. It's great to be Spider-Man. For Peter Parker, there's no feeling quite like swinging between skyscrapers, embracing being the hero, and spending time with Gwen. But being Spider-Man comes at a price: only Spider-Man can protect his fellow New Yorkers from the formidable villains that threaten the city. With the emergence of Electro, Peter must confront a foe far more powerful than he. And as his old friend, Harry Osborn, returns, Peter comes to realize that all of his enemies have one thing in common: Oscorp.",
#   'Rated': 'PG-13',
#   'Title': 'The Amazing Spider-Man 2',
#   'Year': '2014'},
# ...

# %%
len(full_plot)
# Out:
# 89

# %%
movie_df=pd.DataFrame(full_plot)

# %%
movie_df=movie_df[["Title", "Year", "Rated", "Genre(s)", "Plot"]]

# %%
movie_df.head(20)
# Out:
#                                   Title  Year  Rated  \
# 0              The Amazing Spider-Man 2  2014  PG-13
# 1                          The Sessions  2012      R
# 2                       Song of the Sea  2014     PG
# 3                 Safety Not Guaranteed  2012      R
# 4                            Undefeated  2011  PG-13
# 5                                 Turbo  2013     PG
# 6                     To Rome with Love  2012      R
# 7            Resident Evil: Retribution  2012      R
# 8                          End of Watch  2012      R
# 9        Percy Jackson: Sea of Monsters  2013     PG
# 10                           Snow White  2012  PG-13
# 11                          You're Next  2011      R
# 12                     Django Unchained  2012      R
# 13                        Why Stop Now?  2012      R
# 14                             The Loft  2014      R
# 15                          Game Change  2012  TV-MA
# 16                            Bad Karma  2012      R
# ...

# %%
movie_df.to_csv('movies8_full_92.csv', index=False)
